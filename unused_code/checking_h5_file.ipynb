# %%
import numpy as np
import pandas as pd

# %%
a = pd.read_hdf("machinelabels-iter0.h5")
a
# Out:
# scorer                                             DLC_resnet152_dlc_realApr6shuffle32_200000  \
# bodyparts                                                                            left_ear
# coords                                                                                      x
# labeled-data/Control_3_Day_1_cropped/img000296.png                                 428.432617
# labeled-data/Control_3_Day_1_cropped/img002829.png                                 115.540038
# labeled-data/Control_3_Day_1_cropped/img005013.png                                  96.169663
# labeled-data/Control_3_Day_1_cropped/img005841.png                                 111.281996
# labeled-data/Control_3_Day_1_cropped/img006463.png                                        NaN
# labeled-data/Control_3_Day_1_cropped/img006592.png                                        NaN
# labeled-data/Control_3_Day_1_cropped/img006595.png                                        NaN
# ...

# %%
b = pd.read_csv("machinelabels.csv", header=[0,1,2], index_col=0)
b
# Out:
# scorer                                             DLC_resnet152_dlc_realApr6shuffle32_200000  \
# bodyparts                                                                            left_ear
# coords                                                                                      x
# labeled-data/Control_3_Day_1_cropped/img007756.png                                 141.387299
# labeled-data/Control_3_Day_1_cropped/img021383.png                                  52.294762
# labeled-data/Control_3_Day_1_cropped/img011019.png                                 139.049744
# labeled-data/Control_3_Day_1_cropped/img018447.png                                  94.768295
# labeled-data/Control_3_Day_1_cropped/img082832.png                                  66.836906
# labeled-data/Control_3_Day_1_cropped/img020303.png                                 585.526733
# labeled-data/Control_3_Day_1_cropped/img021964.png                                 372.213348
# ...

# %%
a == b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-eeadcaeab874> in <module>
# ----> 1 a == b
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     837             if not self._indexed_same(other):
#     838                 raise ValueError(
# --> 839                     "Can only compare identically-labeled DataFrame objects"
#     840                 )
#     841             new_data = dispatch_to_series(self, other, op, str_rep)
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
a[a != b]

# %%
b[a != b]
