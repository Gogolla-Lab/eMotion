# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
csv_folder = "/Users/onurserce/Desktop/server_mirror/"

dataframes = []

for file in os.listdir(csv_folder):
    if file.endswith(".csv"):
        print("appending", file)
        file_df = pd.read_csv(csv_folder+file, index_col=0)
        file_df["model"] = file.split("_")[1]
        if "200000" not in file:
            dataframes.append(file_df)
        
df = pd.concat(dataframes, axis=0, ignore_index=True)

#df = df.sort_values(by=" Test error(px)", ascending=True)
df = df.sort_values(by="Test error with p-cutoff", ascending=True)
df = df[(df["Training iterations:"] != 50000) & (df["Training iterations:"] != 201000)]

df.head(10)
# Out:
# appending DLC_resnet101_dlc_realApr6shuffle4_201000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle12_200000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle22_200000-results.csv
# appending DLC_resnet50_dlc_realApr6shuffle0_201000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle32_201000-results.csv
# appending DLC_resnet101_dlc_realApr6shuffle16_201000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle8_201000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle6_200000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle14_200000-results.csv
# appending DLC_resnet101_dlc_realApr6shuffle28_201000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle7_200000-results.csv
# appending DLC_resnet50_dlc_realApr6shuffle24_201000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle15_200000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle4_200000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle20_200000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle20_201000-results.csv
# appending DLC_resnet152_dlc_realApr6shuffle23_200000-results.csv
# appending DLC_resnet50_dlc_realApr6shuffle12_201000-results.csv
#     Training iterations:  %Training dataset  Shuffle number   Train error(px)  \
# 12                150000                 90              32              4.08
# 11                100000                 90              32              4.84
# 16                100000                 90              16              6.98
# 13                200000                 90              32              4.05
# 18                200000                 90              16              5.78
# 17                150000                 90              16              5.48
# 21                100000                 90               8              4.83
# 23                200000                 90               8              4.38
# 1                 100000                 90               4              5.25
# 22                150000                 90               8              4.21
#
#      Test error(px)  p-cutoff used  Train error with p-cutoff  \
# 12             8.12           0.85                       2.29
# 11             9.88           0.85                       2.79
# 16            15.30           0.85                       2.91
# 13             8.10           0.85                       2.25
# 18            12.92           0.85                       2.51
# 17            12.91           0.85                       2.67
# 21            15.64           0.85                       2.21
# 23            16.79           0.85                       2.04
# 1             12.65           0.85                       2.56
# 22            16.49           0.85                       2.16
#
#     Test error with p-cutoff      model
# 12                      3.71  resnet152
# 11                      3.71  resnet152
# 16                      3.82  resnet101
# 13                      3.90  resnet152
# 18                      3.93  resnet101
# 17                      3.98  resnet101
# 21                      4.00  resnet152
# 23                      4.10  resnet152
# 1                       4.14  resnet101
# 22                      4.16  resnet152

# %%
df.drop(df.columns[[1, 3, 5, 6]], axis=1).groupby(["Shuffle number", "Training iterations:"]).describe()
# Out:
#                                      Test error(px)                           \
#                                               count   mean std    min    25%
# Shuffle number Training iterations:
# 0              100000                           1.0  15.00 NaN  15.00  15.00
#                150000                           1.0  15.20 NaN  15.20  15.20
#                200000                           1.0  14.86 NaN  14.86  14.86
# 4              100000                           1.0  12.65 NaN  12.65  12.65
#                150000                           1.0  13.68 NaN  13.68  13.68
# 12             100000                                    1.0  6.65 NaN  6.65
#                150000                                    1.0  7.42 NaN  7.42
#                200000                                    1.0  6.51 NaN  6.51
# 16             100000                                    1.0  3.82 NaN  3.82
#                150000                                    1.0  3.98 NaN  3.98
#                200000                                    1.0  3.93 NaN  3.93
# 20             100000                                    1.0  5.40 NaN  5.40
#                150000                                    1.0  5.34 NaN  5.34
#                200000                                    1.0  5.35 NaN  5.35
# 24             100000                                    1.0  7.00 NaN  7.00
#                150000                                    1.0  6.86 NaN  6.86
#                200000                                    1.0  6.84 NaN  6.84
# 28             100000                                    1.0  5.31 NaN  5.31
#                150000                                    1.0  5.37 NaN  5.37
#                200000                                    1.0  5.33 NaN  5.33
# 32             100000                                    1.0  3.71 NaN  3.71
#                150000                                    1.0  3.71 NaN  3.71
#                200000                                    1.0  3.90 NaN  3.90
#
#
#                                       25%   50%   75%   max
# Shuffle number Training iterations:
# 0              100000                5.23  5.23  5.23  5.23
#                150000                5.36  5.36  5.36  5.36
#                200000                5.33  5.33  5.33  5.33
# 4              100000                4.14  4.14  4.14  4.14
#                150000                6.61  6.61  6.61  6.61
#                200000                6.54  6.54  6.54  6.54
# 8              100000                4.00  4.00  4.00  4.00
#                150000                4.16  4.16  4.16  4.16
#                200000                4.10  4.10  4.10  4.10
# 12             100000                6.65  6.65  6.65  6.65
#                150000                7.42  7.42  7.42  7.42
#                200000                6.51  6.51  6.51  6.51
# 16             100000                3.82  3.82  3.82  3.82
#                150000                3.98  3.98  3.98  3.98
#                200000                3.93  3.93  3.93  3.93
# 20             100000                5.40  5.40  5.40  5.40
#                150000                5.34  5.34  5.34  5.34
#                200000                5.35  5.35  5.35  5.35
# 24             100000                7.00  7.00  7.00  7.00
#                150000                6.86  6.86  6.86  6.86
#                200000                6.84  6.84  6.84  6.84
# 28             100000                5.31  5.31  5.31  5.31
#                150000                5.37  5.37  5.37  5.37
#                200000                5.33  5.33  5.33  5.33
# 32             100000                3.71  3.71  3.71  3.71
#                150000                3.71  3.71  3.71  3.71
#                200000                3.90  3.90  3.90  3.90

# %%
sns.lineplot(data=df, x="Training iterations:", y="Test error with p-cutoff", hue="model", style="model")

# %%
sns.boxplot(data=df, x=" Test error(px)", y="model", hue="Training iterations:")

# %%
sns.boxplot(data=df, x="Test error with p-cutoff", y="model", hue="Training iterations:")

# %%
sns.catplot(data=df, y="Test error with p-cutoff", x="model", col="Training iterations:", kind="box")

# %%
sns.catplot(data=df, y=" Test error(px)", x="model", col="Training iterations:", kind="box")

# %% [markdown]
# ## Conclusion:
#
# resnet50 performs the worst
# resnet152 shuffle number 32 looks like an outlier.
#
# **the most logical thing might be to proceed with the outlier extraction with all 3 shuffles of resnet152 and resnet101 models**
