# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import pims

# %%
video = pims.Video(r"J:\Alja Podgornik\Multimaze arena\Cohort 1_June 2020\all_videos\HR5_Day2.mp4")
frame = video[150]
# Out:
# deprecated pixel format used, make sure you did set range correctly
# C:\Users\serce\AppData\Local\Continuum\anaconda3\envs\behaviour-switching\lib\site-packages\pims\pyav_reader.py:232: MethodDeprecationWarning: VideoStream.seek is deprecated.
#   self._stream.seek(timestamp + self._first_pts)
# deprecated pixel format used, make sure you did set range correctly

# %%
plt.imshow(frame)

# %%
from maskROIs import maskFrame_circle

# %%
circled = maskFrame_circle(frame, ((500, 500), 229), color=(255, 255, 50))

# %%
plt.imshow(circled)
